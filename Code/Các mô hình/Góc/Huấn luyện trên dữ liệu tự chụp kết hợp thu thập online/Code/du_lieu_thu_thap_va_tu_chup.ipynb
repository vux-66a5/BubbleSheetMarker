# %%
! pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 901.7/901.7 kB 43.3 MB/s eta 0:00:00
# ...

# %%
! unzip /content/BubbleSheetCorner.v2i.yolov8.zip
# Out:
# Archive:  /content/BubbleSheetCorner.v2i.yolov8.zip
#   inflating: README.dataset.txt
#   inflating: README.roboflow.txt
#   inflating: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/black_120_frame_002_jpg.rf.d4b0fe522b2348d264a7c04784d4fc71.jpg
#  extracting: test/images/black_120_frame_014_jpg.rf.0e56605bd9e2d4c34a99a27accb9bda3.jpg
#  extracting: test/images/black_120_frame_025_jpg.rf.98e3d1864160a21bc918eda37a87043a.jpg
#  extracting: test/images/black_120_frame_035_jpg.rf.d9d672bbcb105314e498d439a24f2b66.jpg
#  extracting: test/images/black_120_frame_060_jpg.rf.9d6ccdac55eaf33880ee09d696623f19.jpg
#  extracting: test/images/black_50_frame_035_jpg.rf.d962f8ae368e1f0c2eac8d43f300b9e2.jpg
#  extracting: test/images/gv_120_frame_014_jpg.rf.ac38ce41724ef5af98030749a75d32e4.jpg
#  extracting: test/images/gv_120_frame_018_jpg.rf.c684bf547efc480f2728d0046790502b.jpg
# ...

# %%
! yolo task=detect mode=train model=/content/best.pt data=/content/data.yaml epochs=200 imgsz=640 batch=16
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.52 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
# Load model đã huấn luyện
model = YOLO('/content/runs/detect/train/weights/best.pt')

# Chạy inference trên tập test
# results = model('/content/drive/MyDrive/FaceAntiSpoofing/data/test/images/1-10-_png.rf.80cfb1d9b9a7ac32c87599237515d2ae.jpg', save=True)
results = model('/content/Screenshot 2024-12-21 at 02.30.52.png', iou=0.1)

# Lấy hình ảnh với kết quả inference
result_image = results[0].plot()

# Hiển thị ảnh
plt.figure(figsize=(10, 10))
plt.imshow(result_image)
plt.axis('off')
plt.show()
# Out:
# image 1/1 /content/Screenshot 2024-12-21 at 02.30.52.png: 640x384 4 corners, 7.3ms
# Speed: 2.1ms preprocess, 7.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
# Load model đã huấn luyện
model = YOLO('/content/runs/detect/train/weights/best.pt')

# Chạy inference trên tập test
# results = model('/content/drive/MyDrive/FaceAntiSpoofing/data/test/images/1-10-_png.rf.80cfb1d9b9a7ac32c87599237515d2ae.jpg', save=True)
results = model('/content/Screenshot 2024-12-21 at 02.32.29.png', iou=0.1)

# Lấy hình ảnh với kết quả inference
result_image = results[0].plot()

# Hiển thị ảnh
plt.figure(figsize=(10, 10))
plt.imshow(result_image)
plt.axis('off')
plt.show()
# Out:
# image 1/1 /content/Screenshot 2024-12-21 at 02.32.29.png: 640x416 4 corners, 7.3ms
# Speed: 2.0ms preprocess, 7.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 416)

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
# Load model đã huấn luyện
model = YOLO('/content/runstancuongdata/detect/train/weights/best.pt')

# Chạy inference trên tập test
# results = model('/content/drive/MyDrive/FaceAntiSpoofing/data/test/images/1-10-_png.rf.80cfb1d9b9a7ac32c87599237515d2ae.jpg', save=True)
results = model('/content/470053044_2284879695204899_2587822334145030960_n.jpg', iou=0.1)

# Lấy hình ảnh với kết quả inference
result_image = results[0].plot()

# Hiển thị ảnh
plt.figure(figsize=(10, 10))
plt.imshow(result_image)
plt.axis('off')
plt.show()
# Out:
# image 1/1 /content/470053044_2284879695204899_2587822334145030960_n.jpg: 640x480 4 corners, 11.8ms
# Speed: 7.5ms preprocess, 11.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
